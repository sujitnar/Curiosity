# %% [markdown]
# The Rössler system is given by the equations:
#
# $$\dot{x}=−y−z;\quad \dot{y} = x + ay; \quad \dot{z} = b + z(x−c)$$
# which for certain parameter values of a
# ,b and c will exhibit chaotic behavior. I have chosen (a,b,c)=(0.1,0.1,14) .The following code simulates the dynamics for the system. First we import some packages and define the Rössler equations.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
a = 0.2
b = 0.2
c = 14
delta_t = 0.01

# %%
def rossler_attractor(x, y, z, a, b, c):
    x_dot = - y - z
    y_dot = x + a*y
    z_dot = b + z*(x - c)

    return x_dot, y_dot, z_dot

# %%
step_size = 0.01 
steps = 100000

# initialize solutions arrays (+1 for initial conditions)
xx = np.empty((steps + 1))
yy = np.empty((steps + 1))
zz = np.empty((steps + 1))

# fill in initial conditions
xx[0], yy[0], zz[0] = (0.1, 0., 0.1)

# %%
# solve equation system
for i in range(steps):
    # Calculate derivatives
    x_dot, y_dot, z_dot = rossler_attractor(xx[i], yy[i], zz[i], a=a, b=b, c=c)
    
    xx[i + 1] = xx[i] + (x_dot * delta_t)
    yy[i + 1] = yy[i] + (y_dot * delta_t)
    zz[i + 1] = zz[i] + (z_dot * delta_t)

# %%
fig = plt.figure(figsize=(5,5))
ax = plt.subplot(projection='3d')
ax.set_facecolor('black')
ax.grid(False)
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.w_xaxis.set_pane_color((0.0, 0.0, 0.0, 1.0))
ax.w_yaxis.set_pane_color((0.0, 0.0, 0.0, 1.0))
ax.w_zaxis.set_pane_color((0.0, 0.0, 0.0, 1.0))

ax.plot(xx, yy, zz,'-',color='white',lw=0.1)
# Out:
# /var/folders/dn/t1jyr93n2pz9t132yhd9jdmm0000gn/T/ipykernel_5335/3072928506.py:8: MatplotlibDeprecationWarning: The w_xaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use xaxis instead.
#   ax.w_xaxis.set_pane_color((0.0, 0.0, 0.0, 1.0))
# /var/folders/dn/t1jyr93n2pz9t132yhd9jdmm0000gn/T/ipykernel_5335/3072928506.py:9: MatplotlibDeprecationWarning: The w_yaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use yaxis instead.
#   ax.w_yaxis.set_pane_color((0.0, 0.0, 0.0, 1.0))
# /var/folders/dn/t1jyr93n2pz9t132yhd9jdmm0000gn/T/ipykernel_5335/3072928506.py:10: MatplotlibDeprecationWarning: The w_zaxis attribute was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use zaxis instead.
#   ax.w_zaxis.set_pane_color((0.0, 0.0, 0.0, 1.0))
